# %%
import numpy as np
import random
l=list(range(100))
random.shuffle(l)
l
# Out:
# [42,
#  1,
#  9,
#  73,
#  52,
#  84,
#  14,
#  13,
#  41,
#  64,
#  45,
#  81,
#  11,
#  47,
#  76,
#  83,
#  55,
#  10,
#  4,
#  63,
#  67,
#  36,
#  17,
#  79,
#  28,
#  44,
#  89,
#  51,
#  87,
#  82,
#  21,
#  2,
#  30,
#  68,
#  93,
#  96,
#  16,
#  18,
#  7,
#  58,
#  62,
#  5,
#  85,
#  50,
#  48,
#  95,
#  60,
#  49,
#  35,
#  57,
#  53,
#  20,
#  86,
#  23,
#  75,
#  15,
#  12,
#  32,
#  39,
#  59,
#  72,
#  61,
#  78,
#  98,
#  70,
#  88,
#  37,
#  25,
#  0,
#  69,
#  99,
#  46,
#  6,
#  33,
#  19,
#  91,
#  26,
#  80,
#  92,
#  38,
#  94,
#  3,
#  77,
#  56,
#  27,
#  8,
#  97,
#  66,
#  71,
#  24,
#  54,
#  74,
#  31,
#  34,
#  90,
#  29,
#  43,
#  40,
#  22,
#  65]

# %%
q=21
isfound=False
for i in l:
    if i==q:
        print("Found")
        isfound=True
if isfound==False:
    print("notfound")
# Out:
# Found

# %%
import math
l=[21,25,26,31,32,34,35,48,49,50,55]
def b(arr,l,r,x):
    if r>=l:
        mid=1+math.floor((r-1/2))
        if arr[mid]==x:
            return mid
        elif arr[mid]>x:
            return b(arr,l,mid-1,x)
        else:
            return b(arr,mid+1,r,x)
    else:
            return -1
l.sort();
arr=l;
q=31
b(arr,0,len(arr)-1,q)
# Out:
# 3

# %%
l1=list(range(100))
random.shuffle(l1)
l2=list(range(50))
random.shuffle(l2)
cnt=0
for i in l1:
    for j in l2:
        cnt+=1
        print(j)
print(cnt)
# Out:
# 15
# 3
# 30
# 44
# 35
# 32
# 37
# 29
# 8
# 43
# 12
# 5
# 10
# 42
# 20
# 47
# 22
# 6
# 0
# 31
# 17
# 25
# 49
# 14
# 38
# 9
# 27
# 33
# 46
# 11
# 16
# 13
# 28
# 21
# 45
# 39
# 18
# 41
# 48
# 34
# 40
# 36
# 23
# 4
# 24
# 7
# 19
# 2
# 1
# 26
# 15
# 3
# 30
# 44
# 35
# 32
# 37
# 29
# 8
# 43
# 12
# 5
# 10
# 42
# 20
# 47
# 22
# 6
# 0
# 31
# 17
# 25
# 49
# 14
# 38
# 9
# 27
# 33
# 46
# 11
# 16
# 13
# 28
# 21
# 45
# 39
# 18
# 41
# 48
# 34
# 40
# 36
# 23
# 4
# 24
# 7
# 19
# 2
# 1
# 26
# 15
# 3
# 30
# 44
# 35
# 32
# 37
# 29
# 8
# 43
# 12
# 5
# 10
# 42
# 20
# 47
# 22
# 6
# 0
# 31
# 17
# 25
# 49
# 14
# 38
# 9
# 27
# 33
# 46
# 11
# 16
# 13
# 28
# 21
# 45
# 39
# 18
# 41
# 48
# 34
# 40
# 36
# 23
# 4
# 24
# 7
# 19
# 2
# 1
# 26
# 15
# 3
# 30
# 44
# 35
# 32
# 37
# 29
# 8
# 43
# 12
# 5
# 10
# 42
# 20
# 47
# 22
# 6
# 0
# 31
# 17
# 25
# 49
# 14
# 38
# 9
# 27
# 33
# 46
# 11
# 16
# 13
# 28
# 21
# 45
# 39
# 18
# 41
# 48
# 34
# 40
# 36
# 23
# 4
# 24
# 7
# 19
# 2
# 1
# 26
# 15
# 3
# 30
# 44
# 35
# 32
# 37
# 29
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset("tips")
sns.barplot(x='day',y='tip',data=tips)

# %%
sns.barplot(x='day',y='total_bill',data=tips)

# %%
sns.barplot(x='day',y='total_bill',data=tips,palette='spring')

# %%
sns.barplot(x='day',y='tip',data=tips,hue='sex')

# %%
sns.barplot(x='day',y='tip',data=tips,hue='sex',palette='coolwarm')

# %%
sns.barplot(x='day',y='tip',data=tips,hue='smoker',palette='coolwarm')

# %%
sns.barplot(x='tip',y='day',data=tips,hue='smoker',palette='coolwarm')

# %% [markdown]
# ## 2-1-2020

# %%
l1=list(range(100))
random.shuffle(l1)
l2=list(range(50))
random.shuffle(l2)
c=0
for i in l1:
    for j in l2:
        if i==j:
            print(j)
        c+=1
print(c)
# Out:
# 41
# 19
# 15
# 36
# 16
# 29
# 4
# 2
# 21
# 39
# 47
# 30
# 23
# 42
# 25
# 34
# 9
# 49
# 18
# 45
# 11
# 24
# 10
# 46
# 7
# 12
# 8
# 6
# 0
# 14
# 22
# 37
# 1
# 26
# 17
# 32
# 48
# 20
# 44
# 40
# 35
# 28
# 13
# 5
# 27
# 3
# 31
# 43
# 38
# 33
# 5000

# %%
l1=list(range(100))
random.shuffle(l1)
l2=list(range(50))
random.shuffle(l2)
sm={}
c=0;
for ele in l2:
    sm[ele]=1
for i in l1:
    if sm.get(i)!=None:
        print(i)
    c+=1
print(c)
# Out:
# 17
# 43
# 29
# 35
# 23
# 39
# 10
# 28
# 42
# 11
# 0
# 14
# 18
# 16
# 2
# 49
# 15
# 46
# 5
# 21
# 33
# 48
# 7
# 8
# 25
# 12
# 27
# 38
# 47
# 13
# 19
# 9
# 20
# 24
# 30
# 3
# 4
# 31
# 45
# 6
# 34
# 41
# 44
# 1
# 22
# 26
# 37
# 40
# 32
# 36
# 100

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv("iris.csv")
print(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
print(iris.shape)
# Out:
# (150, 6)

# %%
print(iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(iris["Species"])
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# 129    Iris-virginica
# ...

# %%
print(iris["Species"].value_counts())
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
iris.plot(kind="scatter",x="SepalLengthCm",y="SepalWidthCm")
plt.show()

# %%
plt.boxplot([iris['PetalWidthCm'],iris['SepalWidthCm'],iris['PetalLengthCm'],iris['SepalLengthCm']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1740848a588>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1740848ac18>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1740848a160>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x174084952e8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x174084955c0>,
# ...
#  'means': []}

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.legend()
plt.show()

# %%
sns.jointplot(iris['SepalLengthCm'],iris['SepalWidthCm'],color='c')

# %%
sns.boxplot(iris['SepalLengthCm'],data = iris,color='g')

# %%
## boxplot & stripplot(for sepallength and all species)
sns.boxplot(iris['SepalWidthCm'],data = iris,color='grey')
plt.show()
sns.stripplot(iris['SepalWidthCm'],data = iris,color='blue')
plt.show()

# %%
sns.violinplot(iris['PetalLengthCm'],iris['Species'])
plt.show()

# %%
import seaborn as sns 
sns.palplot(sns.color_palette())

# %%
from matplotlib import pyplot as plt
current_palette = sns.color_palette("RdBu")
sns.palplot(current_palette)
plt.show()

# %%
sns.palplot(sns.color_palette("RdBu", n_colors=10))

# %%
sns.palplot(sns.color_palette("RdBu",10))

# %%
sns.set()
sns.palplot(sns.cubehelix_palette())

# %%
sns.set()
sns.palplot(sns.cubehelix_palette(rot=-0.1))

# %%
sns.set()
sns.palplot(sns.cubehelix_palette(start=2.1,rot=-.1,reverse=True))

# %%
sns.set()
sns.palplot(sns.cubehelix_palette(reverse=True))

# %%
from numpy import arange
x = arange(16).reshape(4, 4)
cmap = sns.cubehelix_palette(as_cmap=True,rot=-.1)
ax = sns.heatmap(x,cmap=cmap)

# %%
cmap = sns.cubehelix_palette(dark=0, light=1,as_cmap=True)
ax=sns.heatmap(x,cmap=cmap)

# %%
sns.palplot(sns.color_palette("ch:"))
